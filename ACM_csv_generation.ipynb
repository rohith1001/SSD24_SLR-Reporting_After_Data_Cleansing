# %%
pip install pybtex
# Out:
# ...
#      |████████████████████████████████| 286kB 7.7MB/s
# ...

# %%
from pybtex.database.input import bibtex
import pandas as pd
import string

# %%
parser = bibtex.Parser()
bib_data1 = parser.parse_file('SSD bibtexts ACM.txt')
print(bib_data1)
# Out:
# BibliographyData(
#   entries=OrderedCaseInsensitiveDict([
#     ('10.1145/2384716.2384763', Entry('inproceedings',
#       fields=[
#         ('title', 'CnC-Python: Multicore Programming with High Productivity'),
#         ('year', '2012'),
#         ('isbn', '9781450315630'),
#         ('publisher', 'Association for Computing Machinery'),
#         ('address', 'New York, NY, USA'),
#         ('url', 'https:
#         //doi.org/10.1145/2384716.2384763'), ('doi', '10.1145/2384716.2384763'),
#         ('abstract', "We present CnC-Python (CP), an approach to implicit multicore parallelism based on Intel's Concurrent Collections model. CP enables programmers to achieve task, data and pipeline parallelism in a declarative fashion while only being required to describe the program as a coordination graph with serial Python code for individual nodes."),
#         ('booktitle', 'Proceedings of the 3rd Annual Conference on Systems, Programming, and Applications: Software for Humanity'),
# ...

# %%
bib_data1.entries.keys()
df=pd.DataFrame()
author_dict={}
id_ls=[]
abstract={}
booktitle={}
title={}
year={}
volume={}
number={}
pages={}
keywords={}
doi={}
issn={}
author1={}
months={}
isbn={}
publisher={}
address={}
url={}
doi={}
numpages={}
location={}
series={}

for id in bib_data1.entries:
  id_ls.append(id)
  abstract[id]=bib_data1.entries[id].fields['abstract']

  try:
    booktitle[id]=bib_data1.entries[id].fields['booktitle']
  except KeyError:
    booktitle[id]='none'

  title[id]=bib_data1.entries[id].fields['title']

  year[id]=bib_data1.entries[id].fields['year']

  try:
    months[id]=bib_data1.entries[id].fields['month']
  except KeyError:
    months[id]=np.NaN

  try:
    volume[id]=bib_data1.entries[id].fields['volume']
  except KeyError:
    volume[id]='none'

  try:
    number[id]=bib_data1.entries[id].fields['number']
  except KeyError:
    number[id]='none'

  try:
    pages[id]=bib_data1.entries[id].fields['pages']
  except KeyError:
    pages[id] = 'none'

  try:
    keywords[id]=bib_data1.entries[id].fields['keywords']
  except KeyError:
    keywords[id]='none'

  try:
    doi[id]=bib_data1.entries[id].fields['doi']
  except KeyError:
    doi[id]='none'

  try:
    issn[id]=bib_data1.entries[id].fields['ISSN']
  except KeyError:
    issn[id]='none'

  try:
    isbn[id]=bib_data1.entries[id].fields['isbn']
  except KeyError:
    isbn[id]='none'

  try:
    publisher[id]=bib_data1.entries[id].fields['publisher']
  except KeyError:
    publisher[id]='none'

  try:
    address[id]=bib_data1.entries[id].fields['address']
  except KeyError:
    address[id]='none'

  try:
    url[id]=bib_data1.entries[id].fields['url']
  except KeyError:
    url[id]='none'

  try:
    numpages[id]=bib_data1.entries[id].fields['numpages']
  except KeyError:
    numpages[id]='none'

  try:
    location[id]=bib_data1.entries[id].fields['location']
  except KeyError:
    location[id]='none'  

  try:
    series[id]=bib_data1.entries[id].fields['series']
  except KeyError:
    series[id]='none'


  authors = ""
  translator = str.maketrans('', '', string.punctuation)
  for author in bib_data1.entries[id].persons["author"]:
      new_author = str(author.first_names) + " " + str(author.last_names) 
      new_author = new_author.translate(translator)
      if len(authors) == 0:
        authors = "" + new_author
      else:
        authors = authors + ", " + new_author

  author_dict[id]=authors

df['id']=id_ls
df['author']=df['id'].map(author_dict)
df['abstract']=df['id'].map(abstract)
df['booktitle']=df['id'].map(booktitle)
df['title']=df['id'].map(title)
df['year']=df['id'].map(year)
df['volume']=df['id'].map(volume)
df['number']=df['id'].map(number)
df['pages']=df['id'].map(pages)
df['keywords']=df['id'].map(keywords)
df['doi']=df['id'].map(doi)
df['ISSN']=df['id'].map(issn)
df['months']=df['id'].map(months)
df['isbn']=df['id'].map(isbn)
df['publisher']=df['id'].map(publisher)
df['address']=df['id'].map(address)
df['url']=df['id'].map(url)
df['numpages']=df['id'].map(numpages)
df['location']=df['id'].map(location)
df['series']=df['id'].map(series)
df.to_csv('ACM_Oct21.csv')
